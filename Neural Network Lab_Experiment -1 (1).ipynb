# %% [markdown]
# # **READ TEXT FILE THROUGH PYTHON & APPLYING WRITE,READ AND APPEND**

# %%
import pandas as pd

# %%
data=pd.read_table("/content/demo.txt")
data.head()
# Out:
#                  Akhil Sharma
# 0  Fav series Vampire diaries

# %% [markdown]
# # **Implementing Write Operation on text file**

# %%
tfile=open("/content/demo.txt","w")
tfile.write("see yaaa guyss!!")
tfile.close()

# %%
data=pd.read_table("/content/demo.txt")
data.head()
# Out:
# Empty DataFrame
# Columns: [see yaaa guyss!!]
# Index: []

# %% [markdown]
# # ***Implementing Append Operation on Text File***

# %%
tfile=open("/content/demo.txt","a")
tfile.write("chalo jaane doo...ab chordoo bhiiii")
tfile.close()

# %%
data=pd.read_table("/content/demo.txt")
data.head()
# Out:
# Empty DataFrame
# Columns: [see yaaa guyss!!chalo jaane doo...ab chordoo bhiiii]
# Index: []

# %% [markdown]
# # **Reading CSV FILE AND APPLYING WRITE,READ AND APPEND**

# %%
data=pd.read_csv("/content/Test.csv")
data.head()
# Out:
#    S.no    Name  Age     Lang
# 0     1   Rohan   18  English
# 1     2  Upasna   20    Hindi
# 2     3  Ramesh   21    Hindi
# 3     4   Ronak   18  English
# 4     5  Sumati   24  English

# %%
data = {
	'S.no': [6],
	'Name': ['Bhawana'],
	'Age': [25],
	'Lang': ['English']
}

df = pd.DataFrame(data)

df.to_csv('/content/Test.csv', mode='a', index=False, header=False)

print("Data appended successfully.")
# Out:
# Data appended successfully.

# %%
data=pd.read_csv("/content/Test.csv")
data.head(6)
# Out:
#    S.no     Name  Age     Lang
# 0     1    Rohan   18  English
# 1     2   Upasna   20    Hindi
# 2     3   Ramesh   21    Hindi
# 3     4    Ronak   18  English
# 4     5   Sumati   24  English
# 5     6  Bhawana   25  English

# %% [markdown]
# # **Implementing Write operation on CSV file**

# %%
data = {
	'S.no': [1],
	'Name': ['Rituja'],
	'Age': [20],
	'Lang': ['Hindi']
}

df = pd.DataFrame(data)

df.to_csv('/content/Test.csv', mode='w', index=False, header=False)

print("Data Written successfully.")
# Out:
# Data Written successfully.

# %% [markdown]
# # **Implementing Append operation on CSV file**

# %%
data=pd.read_csv("/content/Test.csv")
data.head()
# Out:
# Empty DataFrame
# Columns: [1, Rituja, 20, Hindi]
# Index: []
